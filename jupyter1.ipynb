# %%
import cv2
import pandas as pd
from ultralytics import YOLO
from tracker import Tracker
import time

model = YOLO('yolov8s.pt')

def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        colorsBGR = [x, y]
        print(colorsBGR)

cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

cap = cv2.VideoCapture('traffic1.mp4')

my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")

count = 0
tracker = Tracker()
vh_down = {}
counter = []
vh_up = {}
counter1 = []
vh_dtime = {}
vh_utime = {}
cy1 = 322
cy2 = 368
offset = 6

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output.mp4', fourcc, 20.0, (1020, 500))

def display_speed(frame, cx, cy, vehicle_id, counter_list, elapsed_time, x, y):
    cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
    cv2.putText(frame, str(vehicle_id), (cx, cy), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

    if vehicle_id not in counter_list:
        counter_list.append(vehicle_id)

    distance = 10

    if elapsed_time > 0:
        speed_ms = distance / elapsed_time
        speed_km = speed_ms * 3.6
        cv2.putText(frame, str(int(speed_km)) + ' Km/h', (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)
    else:
        cv2.putText(frame, 'Speed N/A', (x, y), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    count += 1
    if count % 3 != 0:
        continue

    frame = cv2.resize(frame, (1020, 500))

    results = model.predict(frame)
    a = results[0].boxes.data
    px = pd.DataFrame(a).astype("float")

    list = []

    for index, row in px.iterrows():
        x1, y1, x2, y2, _, d = map(int, row)
        c = class_list[d]

        if c in ['car', 'truck', 'bus']:
            list.append([x1, y1, x2, y2])

    bbox_id = tracker.update(list)

    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox
        cx = (x3 + x4) // 2
        cy = (y3 + y4) // 2

        if cy1 - offset < cy < cy1 + offset:
            vh_down[id] = cy
            vh_dtime[id] = time.time()

        if cy2 - offset < cy < cy2 + offset:
            vh_up[id] = cy
            vh_utime[id] = time.time()

        cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 1)
        if id in vh_down:
            elapsed_time = time.time() - vh_dtime[id]
            display_speed(frame, cx, cy, id, counter, elapsed_time, x4, y4)
        if id in vh_up:
            elapsed_time2 = time.time() - vh_utime[id]
            display_speed(frame, cx, cy, id, counter1, elapsed_time2, x4, y4)

    cv2.line(frame, (267, cy1), (829, cy1), (255, 255, 255), 1)
    cv2.putText(frame, '1line', (274, 318), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

    cv2.line(frame, (167, cy2), (932, cy2), (255, 255, 255), 1)
    cv2.putText(frame, '2line', (181, 363), cv2.FONT_HERSHEY_COMPLEX, 0.8, (0, 255, 255), 2)

    cv2.putText(frame, 'GoingDown: ' + str(len(counter)), (60, 40), cv2.FONT_HERSHEY_COMPLEX, 0.7, (255, 0, 0), 2)
    cv2.putText(frame, 'GoingUp: ' + str(len(counter1)), (60, 130), cv2.FONT_HERSHEY_COMPLEX, 0.7, (255, 0, 0), 2)

    out.write(frame)

    cv2.imshow("RGB", frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 3 cars, 534.5ms
# Speed: 9.1ms preprocess, 534.5ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
# [864, 499]
# 0: 320x640 3 cars, 507.5ms
# Speed: 7.2ms preprocess, 507.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 3 cars, 1 truck, 555.8ms
# Speed: 6.6ms preprocess, 555.8ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 truck, 488.1ms
# Speed: 7.3ms preprocess, 488.1ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 2 trucks, 537.0ms
# Speed: 6.6ms preprocess, 537.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 truck, 430.1ms
# Speed: 6.0ms preprocess, 430.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 1 truck, 439.6ms
# Speed: 6.0ms preprocess, 439.6ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 1 truck, 447.8ms
# Speed: 7.0ms preprocess, 447.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 truck, 443.7ms
# Speed: 5.5ms preprocess, 443.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 1 truck, 440.0ms
# Speed: 5.7ms preprocess, 440.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 truck, 309.0ms
# Speed: 2.7ms preprocess, 309.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 truck, 315.9ms
# Speed: 4.0ms preprocess, 315.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 1 truck, 319.4ms
# Speed: 2.0ms preprocess, 319.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 355.6ms
# Speed: 8.5ms preprocess, 355.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 282.0ms
# Speed: 3.5ms preprocess, 282.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars,
6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 4 trucks, 468.6ms
# Speed: 6.1ms preprocess, 468.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 3 trucks, 406.1ms
# Speed: 3.5ms preprocess, 406.1ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 3 trucks, 475.7ms
# Speed: 5.6ms preprocess, 475.7ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 3 trucks, 464.3ms
# Speed: 8.0ms preprocess, 464.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 1 bus, 1 train, 2 trucks, 465.8ms
# Speed: 6.6ms preprocess, 465.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 2 trucks, 415.4ms
# Speed: 6.0ms preprocess, 415.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 3 trucks, 406.0ms
# Speed: 4.0ms preprocess, 406.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 3 trucks, 448.1ms
# Speed: 4.5ms preprocess, 448.1ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 7 cars, 3 trucks, 470.5ms
# Speed: 4.0ms preprocess, 470.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 3 trucks, 406.8ms
# Speed: 5.0ms preprocess, 406.8ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 8 cars, 4 trucks, 425.1ms
# Speed: 9.0ms preprocess, 425.1ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 3 trucks, 419.4ms
# Speed: 6.0ms preprocess, 419.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 3 trucks, 522.2ms
# Speed: 5.0ms preprocess, 522.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 4 trucks, 521.7ms
# Speed: 6.0ms preprocess, 521.7ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 2 trucks, 618.4ms
# Speed: 9.1ms preprocess, 618.4ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 3 trucks, 567.7ms
# Speed: 6.0ms preprocess, 567.7ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 2 trucks, 478.5ms
# Speed: 3.0ms preprocess, 478.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 2 trucks, 560.9ms
# Speed: 6.0ms preprocess, 560.9ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 2 trucks, 516.0ms
# Speed: 6.4ms preprocess, 516.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 2 trucks, 508.2ms
# Speed: 6.0ms preprocess, 508.2ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 1 truck, 911.9ms
# Speed: 6.0ms preprocess, 911.9ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 1 truck, 597.4ms
# Speed: 6.5ms preprocess, 597.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 2 trucks, 436.2ms
# Speed: 6.6ms preprocess, 436.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 1 truck, 420.2ms
# Speed: 8.5ms preprocess, 420.2ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 3 cars, 1 truck, 505.3ms
# Speed: 6.0ms preprocess, 505.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 1 truck, 472.5ms
# Speed: 6.9ms preprocess, 472.5ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 2 cars, 1 truck, 782.5ms
# Speed: 7.5ms preprocess, 782.5ms inference, 11.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 2 cars, 1 truck, 487.6ms
# Speed: 7.0ms preprocess, 487.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 3 cars, 1 truck, 662.0ms
# Speed: 5.1ms preprocess, 662.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 2 cars, 1 truck, 449.1ms
# Speed: 5.0ms preprocess, 449.1ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 2 cars, 1 truck, 489.9ms
# Speed: 5.0ms preprocess, 489.9ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 2 cars, 1 truck, 509.7ms
# Speed: 5.0ms preprocess, 509.7ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 2 cars, 1 truck, 427.7ms
# Speed: 5.0ms preprocess, 427.7ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 3 cars, 1 truck, 565.4ms
# Speed: 7.0ms preprocess, 565.4ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 2 cars, 1 truck, 514.2ms
# Speed: 6.6ms preprocess, 514.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 3 cars, 2 trucks, 552.0ms
# Speed: 6.1ms preprocess, 552.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 2 trucks, 512.0ms
# Speed: 4.3ms preprocess, 512.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 2 trucks, 524.5ms
# Speed: 5.1ms preprocess, 524.5ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 2 trucks, 513.1ms
# Speed: 4.4ms preprocess, 513.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 1 bus, 2 trucks, 701.5ms
# Speed: 6.1ms preprocess, 701.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 4 trucks, 433.3ms
# Speed: 5.5ms preprocess, 433.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 3 cars, 1 bus, 3 trucks, 639.5ms
# Speed: 6.0ms preprocess, 639.5ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 3 cars, 1 bus, 4 trucks, 419.4ms
# Speed: 4.5ms preprocess, 419.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 1 bus, 1 truck, 465.7ms
# Speed: 6.4ms preprocess, 465.7ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 5 cars, 1 bus, 1 truck, 471.5ms
# Speed: 7.8ms preprocess, 471.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 6 cars, 1 bus, 2 trucks, 824.9ms
# Speed: 5.0ms preprocess, 824.9ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 4 cars, 1 bus, 1 truck, 758.6ms
# Speed: 9.6ms preprocess, 758.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 640)
